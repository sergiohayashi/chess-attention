# %%
from model_controller import ModelPredictController, ModelTrainController
from plotter import Plotter
from glob import glob
from IPython.display import Image
# Out:
# Found GPU at: /device:GPU:0
# 2.5.0
# Found GPU at: /device:GPU:0
# 2.5.0
# Found GPU at: /device:GPU:0
# Found GPU at: /device:GPU:0
# 2.5.0

# %%
#
# habilitar para tamanho menor
#
from config import config
config["FORCE_INPUT_SIZE"] = {"INPUT_SHAPE": (400, 430), "ATTENTION_SHAPE": (25, 26)}

# %%
model = ModelPredictController(NUM_LINHAS=8, NO_TEACH=False);      ## Ajustar NO_TEACH de acordo com o modelo!!!

# %%
model.load()
# Out:
# Usa FORCE_INPUT_SIZE informada em config.py {"INPUT_SHAPE": [400, 430], "ATTENTION_SHAPE": [25, 26]}
#
# building...
# total do vocabulario=  179
# VOCAB_SIZE 180
# Shape da imagem ao final da CNN:  (None, 25, 26, 512)

# %%
model.restoreFromCheckpointName('train_comparativo_20211106_handwritten_teacher_tam_menor---8linhas-handwritten--5k')
# model.restoreFromBestCheckpoint()
# Out:
# restore from pretraining  ../train-folder/checkpoints/train_comparativo_20211106_handwritten_teacher_tam_menor---8linhas-handwritten--5k\ckpt-1 ...

# %%
model.evaluateForTest('test-8lines-first', plot_attention=True, _len= 16)
# Out:
# target_len=  16
# evaluating dataset  test-8lines-first
# evaluating total images:  2 ...
# evaluating  0 ...
# --------------------<  0 :  carnaval_0287_fullpage.jpg >------------------------------
# len: 16 acc: 0.4375 cer 0.5625 file:  ../test-data/test-8lines-first\images\carnaval_0287_fullpage.jpg
# ../test-data/test-8lines-first\images\carnaval_0287_fullpage.jpg
# --------------------<  1 :  carnaval_0004_fullpage.jpg >------------------------------
# len: 16 acc: 0.5 cer 0.4375 file:  ../test-data/test-8lines-first\images\carnaval_0004_fullpage.jpg
# ../test-data/test-8lines-first\images\carnaval_0004_fullpage.jpg
# [([1.0,
#    1.0,
#    1.0,
#    0.875,
#    0.8999999761581421,
#    0.9166666865348816,
#    0.8571428656578064,
#    0.8125,
#    0.7222222089767456,
#    0.6499999761581421,
#    0.6363636255264282,
#    0.5833333134651184,
#    0.5384615659713745,
#    0.5,
#    0.5,
#    0.46875],
#   [0.0,
#    0.0,
#    0.0,
#    0.0833333358168602,
# ...
