# %%
from model_controller import ModelPredictController, ModelTrainController
from plotter import Plotter
from glob import glob
from IPython.display import Image
# Out:
# Found GPU at: /device:GPU:0
# 2.5.0
# Found GPU at: /device:GPU:0
# 2.5.0
# Found GPU at: /device:GPU:0
# Found GPU at: /device:GPU:0
# 2.5.0

# %%
model = ModelPredictController(NUM_LINHAS=8, NO_TEACH=False);

# %%
model.load()
# Out:
# building...
# total do vocabulario=  179
# VOCAB_SIZE 180
# Shape da imagem ao final da CNN:  (None, 50, 53, 512)

# %%
model.restoreFromCheckpointName('train_comparativo_20211106_handwritten_teacher_10k_---8linhas-handwritten--10k')
# model.restoreFromBestCheckpoint()
# Out:
# restore from pretraining  ../train-folder/checkpoints/train_comparativo_20211106_handwritten_teacher_10k_---8linhas-handwritten--10k\ckpt-2 ...

# %%
model.evaluateForTest('test-8lines-kaito', plot_attention=True, _len= 16)
# Out:
# target_len=  16
# evaluating dataset  test-8lines-kaito
# evaluating total images:  3 ...
# evaluating  0 ...
# --------------------<  0 :  kaito.jpg >------------------------------
# len: 16 acc: 0.5625 cer 0.28125 file:  ../test-data/test-8lines-kaito\images\kaito.jpg
# ../test-data/test-8lines-kaito\images\kaito.jpg
# --------------------<  1 :  carnaval_0004_fullpage.jpg >------------------------------
# len: 16 acc: 0.75 cer 0.13541667 file:  ../test-data/test-8lines-kaito\images\carnaval_0004_fullpage.jpg
# ../test-data/test-8lines-kaito\images\carnaval_0004_fullpage.jpg
# --------------------<  2 :  carnaval_0287_fullpage.jpg >------------------------------
# len: 16 acc: 1.0 cer 0.0 file:  ../test-data/test-8lines-kaito\images\carnaval_0287_fullpage.jpg
# ../test-data/test-8lines-kaito\images\carnaval_0287_fullpage.jpg
# [([0.6666666865348816,
#    0.8333333134651184,
#    0.8888888955116272,
#    0.9166666865348816,
#    0.9333333373069763,
#    0.9444444179534912,
#    0.9523809552192688,
#    0.9166666865348816,
#    0.8888888955116272,
#    0.8333333134651184,
#    0.7878788113594055,
#    0.8055555820465088,
#    0.8205128312110901,
#    0.8095238208770752,
#    0.800000011920929,
#    0.7708333134651184],
#   [0.1666666716337204,
#    0.0833333358168602,
#    0.0555555559694767,
#    0.0416666679084301,
#    0.03333333507180214,
#    0.02777777798473835,
#    0.02380952425301075,
#    0.0416666679084301,
#    0.061728399246931076,
#    0.09444445371627808,
#    0.12121212482452393,
#    0.1111111268401146,
#    0.10256411880254745,
#    0.1111111268401146,
#    0.12037038803100586,
#    0.1388888955116272],
#   'test-8lines-kaito')]
