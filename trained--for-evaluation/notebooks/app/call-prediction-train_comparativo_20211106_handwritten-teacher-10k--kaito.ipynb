# %%
from model_controller import ModelPredictController, ModelTrainController
from plotter import Plotter
from glob import glob
from IPython.display import Image
# Out:
# Found GPU at: /device:GPU:0
# 2.5.0
# Found GPU at: /device:GPU:0
# 2.5.0
# Found GPU at: /device:GPU:0
# Found GPU at: /device:GPU:0
# 2.5.0

# %%
model = ModelPredictController(NUM_LINHAS=8, NO_TEACH=False);

# %%
model.load()
# Out:
# building...
# total do vocabulario=  179
# VOCAB_SIZE 180
# Shape da imagem ao final da CNN:  (None, 50, 53, 512)

# %%
model.restoreFromCheckpointName('train_comparativo_20211106_handwritten_teacher_10k_---8linhas-handwritten--10k')
# model.restoreFromBestCheckpoint()
# Out:
# restore from pretraining  ../train-folder/checkpoints/train_comparativo_20211106_handwritten_teacher_10k_---8linhas-handwritten--10k\ckpt-2 ...

# %%
model.evaluateForTest('test-8lines-kaito', plot_attention=True, _len= 16)
# Out:
# target_len=  16
# evaluating dataset  test-8lines-kaito
# evaluating total images:  4 ...
# evaluating  0 ...
# --------------------<  0 :  kaito--ajustado.jpg >------------------------------
# len: 16 acc: 0.25 cer 0.5833334 file:  ../test-data/test-8lines-kaito\images\kaito--ajustado.jpg
# ../test-data/test-8lines-kaito\images\kaito--ajustado.jpg
# --------------------<  1 :  kaito.jpg >------------------------------
# len: 16 acc: 0.4375 cer 0.39583334 file:  ../test-data/test-8lines-kaito\images\kaito.jpg
# ../test-data/test-8lines-kaito\images\kaito.jpg
# --------------------<  2 :  carnaval_0004_fullpage.jpg >------------------------------
# len: 16 acc: 0.75 cer 0.125 file:  ../test-data/test-8lines-kaito\images\carnaval_0004_fullpage.jpg
# ../test-data/test-8lines-kaito\images\carnaval_0004_fullpage.jpg
# --------------------<  3 :  carnaval_0287_fullpage.jpg >------------------------------
# len: 16 acc: 0.875 cer 0.03125 file:  ../test-data/test-8lines-kaito\images\carnaval_0287_fullpage.jpg
# ../test-data/test-8lines-kaito\images\carnaval_0287_fullpage.jpg
# [([0.5,
#    0.625,
#    0.5833333134651184,
#    0.625,
#    0.699999988079071,
#    0.75,
#    0.7857142686843872,
#    0.75,
#    0.7222222089767456,
#    0.675000011920929,
#    0.6363636255264282,
#    0.625,
#    0.6153846383094788,
#    0.6071428656578064,
#    0.6000000238418579,
#    0.578125],
#   [0.25,
#    0.1875,
#    0.2916666865348816,
#    0.25,
#    0.20000000298023224,
#    0.1666666567325592,
#    0.1428571492433548,
#    0.15625,
#    0.17592594027519226,
#    0.19374999403953552,
#    0.22159090638160706,
#    0.2291666716337204,
#    0.23076923191547394,
#    0.2440476268529892,
#    0.2611111104488373,
#    0.2838541865348816],
#   'test-8lines-kaito')]
