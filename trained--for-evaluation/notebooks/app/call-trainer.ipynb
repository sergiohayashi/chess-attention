# %%
from model_controller import ModelController
# Out:
# Found GPU at: /device:GPU:0
# 2.5.0
# Found GPU at: /device:GPU:0

# %%
model = ModelController();

# %%
model.load()
# Out:
# building...
# total do vocabularario=  179
# VOCAB_SIZE 180

# %%
model.restoreFromBestCheckpoint()
# Out:
# restore from pretraining  ../best_checkpoint/1006/checkpoints/train\ckpt-48 ...

# %%
result, attention, _ = model.predictOneImage("./sample_data/sample-1.jpg")

# %%
result
# Out:
# ['e4', 'c5', 'Nf3', 'e6']

# %%
from plotter import Plotter

# %%
plt = Plotter( model.model)

# %%
plt.plot_attention( "./sample_data/sample-1.jpg", result, attention)
# Out:
# ./sample_data/sample-1.jpg
